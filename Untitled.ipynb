# %%
import os
import my_yolov6
import cv2
import matplotlib.pyplot as plt

# %%
if not os.path.exists(f"yolov6s.pt"):
  print("Downloading checkpoint...")
  os.system(f"""wget -c https://github.com/meituan/YOLOv6/releases/download/0.2.0/yolov6s.pt""")

# %%
yolov6_model = my_yolov6.my_yolov6("yolov6s.pt", "cpu", "./data/coco.yaml", 640, False)
# Out:
# Loading checkpoint from yolov6s.pt
#
# Fusing model...

# %%
frame = cv2.imread('./images/1.JPG')

# %%
frame, no_object = yolov6_model.infer(frame)
# Out:
# /home/vietdoo/Object-Detection-Flask/venv/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
plt.imshow(frame)
